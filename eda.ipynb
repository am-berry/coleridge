# %%
import os
import re
import json

import pandas as pd

# %%
train = pd.read_csv('train.csv')

# %%
labs = set(train['cleaned_label'].tolist())

# %%
os.listdir('./train/')[0]
# Out:
# '75c5eff6-27c1-4fd3-9d35-68e48799e6cd.json'

# %%
with open('./train/' + os.listdir('./train/')[0]) as f:
    d = json.load(f)

# %%
def clean_text(txt):
    return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower())

# %%
long_text = ""
for dic in d:
    for k, v in dic.items():
        long_text += k
        long_text += '$$$$$'
        long_text += v
        long_text += '$$$$$'

# %%
lt = clean_text(long_text)

# %%
for l in labs:
    if l in lt:
        print(l)
# Out:
# adni
# alzheimer s disease neuroimaging initiative adni

# %%
def basic_checker(num):
    # Load the json in
    # Check labs against cleaned json
    train = pd.read_csv('train.csv')
    train_dir = './train/'
    files = os.listdir(train_dir)[:num]
    for fi in files:
        with open(train_dir+fi) as f:
            d = json.load(f)
    long_text = ""
    for dic in d:
        for k, v in dic.items():
            long_text += k
            long_text += '$$$$$'
            long_text += v
            long_text += '$$$$$'
    labs =
# Out:
#   File "<ipython-input-25-093d7f09e464>", line 5
#     for f in files:
#                    ^
# SyntaxError: unexpected EOF while parsing
